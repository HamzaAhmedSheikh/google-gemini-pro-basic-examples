# %%
import os

GOOGLE_API_KEY = os.getenv('GOOGLE_API_KEY')

# %%
import google.generativeai as genai

genai.configure(api_key=GOOGLE_API_KEY)

for m in genai.list_models():
    print(m.name)
    print(m.supported_generation_methods)
# Out:
# models/chat-bison-001
# ['generateMessage', 'countMessageTokens']
# models/text-bison-001
# ['generateText', 'countTextTokens', 'createTunedTextModel']
# models/embedding-gecko-001
# ['embedText', 'countTextTokens']
# models/gemini-pro
# ['generateContent', 'countTokens']
# models/gemini-pro-vision
# ['generateContent', 'countTokens']
# models/embedding-001
# ['embedContent', 'countTextTokens']
# models/aqa
# ['generateAnswer']

# %%
import google.generativeai as genai

genai.configure(api_key=GOOGLE_API_KEY)

# Set up the model
generation_config = {
  "temperature": 0.9,
  "top_p": 1,
  "top_k": 1,
  "max_output_tokens": 2048,
}

safety_settings = [
  {
    "category": "HARM_CATEGORY_HARASSMENT",
    "threshold": "BLOCK_MEDIUM_AND_ABOVE"
  },
  {
    "category": "HARM_CATEGORY_HATE_SPEECH",
    "threshold": "BLOCK_MEDIUM_AND_ABOVE"
  },
  {
    "category": "HARM_CATEGORY_SEXUALLY_EXPLICIT",
    "threshold": "BLOCK_MEDIUM_AND_ABOVE"
  },
  {
    "category": "HARM_CATEGORY_DANGEROUS_CONTENT",
    "threshold": "BLOCK_MEDIUM_AND_ABOVE"
  }
]

model = genai.GenerativeModel(model_name="gemini-pro",
                              generation_config=generation_config,
                              safety_settings=safety_settings)

prompt_parts = [
  "tell me about the biggest planet?",
]

response = model.generate_content(prompt_parts)
print(response.text)
# Out:
# Jupiter is the biggest planet in our solar system. It is a gas giant and is composed mostly of hydrogen and helium. Jupiter is more than twice the mass of all the other planets in the solar system combined. It has a diameter of approximately 142,984 kilometers (88,846 miles), which is 11 times that of Earth.
#
# Jupiter's atmosphere is highly dynamic and contains a complex system of clouds, storms, and winds. The most famous feature of Jupiter's atmosphere is the Great Red Spot, a giant storm that has been raging for at least 400 years.
#
# Jupiter has a very strong magnetic field, which is generated by the movement of liquid metallic hydrogen in its interior. The magnetic field is so strong that it creates a vast magnetosphere, which extends millions of kilometers into space.
#
# Jupiter has at least 80 moons, the largest of which are Ganymede, Callisto, Io, and Europa. Ganymede is the largest moon in the solar system and is even larger than the planet Mercury.
#
# Jupiter is a fascinating and complex planet that has been studied extensively by scientists. It is a treasure trove of information about the formation and evolution of our solar system.

# %% [markdown]
# ### Streaming

# %%
import google.generativeai as genai

genai.configure(api_key=GOOGLE_API_KEY)

# Set up the model
generation_config = {
  "temperature": 0.9,
  "top_p": 1,
  "top_k": 1,
  "max_output_tokens": 2048,
}

safety_settings = [
  {
    "category": "HARM_CATEGORY_HARASSMENT",
    "threshold": "BLOCK_MEDIUM_AND_ABOVE"
  },
  {
    "category": "HARM_CATEGORY_HATE_SPEECH",
    "threshold": "BLOCK_MEDIUM_AND_ABOVE"
  },
  {
    "category": "HARM_CATEGORY_SEXUALLY_EXPLICIT",
    "threshold": "BLOCK_MEDIUM_AND_ABOVE"
  },
  {
    "category": "HARM_CATEGORY_DANGEROUS_CONTENT",
    "threshold": "BLOCK_MEDIUM_AND_ABOVE"
  }
]

model = genai.GenerativeModel(model_name="gemini-pro",
                              generation_config=generation_config,
                              safety_settings=safety_settings)

prompt_parts = [
  "tell me about the smallest planet?",
]

response  = model.generate_content(prompt_parts, stream=True)

print(response)
# Out:
# <google.generativeai.types.generation_types.GenerateContentResponse object at 0x7ff588943ad0>

# %%
for chunk in response:
    print(chunk.text)
# Out:
# The smallest planet in our solar system is Mercury. It is a tiny, rocky
#  world that is only slightly larger than Earth's moon. Mercury has a diameter of just 4,879 kilometers (3,032 miles
# ), which is about one-third the size of Earth. It is also the closest planet to the Sun, orbiting at an average distance of 57.9 million kilometers (35.9 million miles).
#
# Mercury is a fascinating but hostile world. It has a very thin atmosphere, composed mostly of oxygen,
#  sodium, hydrogen, helium, and potassium. The surface temperature of Mercury can reach up to 450 degrees Celsius (842 degrees Fahrenheit) during the day, making it the hottest planet in the solar system. However, the temperature can drop to as low as -180 degrees Celsius (-292 degrees Fahrenheit) at night.
#
# Mercury has a number of unique features that set it apart from the other planets in our solar system. For example, it has a very large iron core, which makes up about 70% of its mass. This core is thought to be the result of a giant impact that
#  occurred early in Mercury's history.
#
# Mercury also has a very weak magnetic field, which is only about 1% as strong as Earth's magnetic field. This weak magnetic field is thought to be caused by the interaction of Mercury's core with the solar wind.
#
# Mercury has been visited by two spacecraft: Mariner 10 in 1974 and 1975, and MESSENGER in 2011-2015. MESSENGER was the first spacecraft to orbit Mercury, and it provided us with a wealth of new information about the planet.
#
# MESSENGER revealed that Mercury has a very complex surface, with a variety of different types of terrain. The surface is covered in craters, which are the result of impacts by asteroids and comets. MESSENGER also discovered that Mercury has a number of volcanic features, including lava flows and domes.
#
# Overall, Mercury is a fascinating and complex planet that is still not fully understood. Future missions to Mercury will help us to learn more about this unique world.
